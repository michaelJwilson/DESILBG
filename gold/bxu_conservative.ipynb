# %%
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt

from selection.bxu import bxu as select_bxu
from selection.u_nondetect import u_nondetect
from astropy.table import Table

# %%
bxu = Table.read('/global/cscratch1/sd/mjwilson/DESILBG/GOLD/BXU/bxu.fits')
yeche = Table.read('/global/u2/y/yeche/LBG/LBG_targets_in_COSMOS.fits')
tmg = Table.read('/global/cscratch1/sd/mjwilson/DESILBG/GOLD/TMGV9/tmg_v9.fits')

# %%
len(bxu)
# Out:
# 12136

# %%
clauds = Table.read('/global/cscratch1/sd/mjwilson/clauds/March2021/COSMOS_v9_v210225.fits')
clauds = clauds[clauds['FLAG_FIELD_BINARY'][:,1] == True]

# %%
stars= Table.read('/global/cscratch1/sd/mjwilson/stars/stars.fits')

# %%
pl.plot(bxu['g']   - bxu['r'], bxu['u'] - bxu['g'], marker='.', lw=0., c='k', markersize=2, alpha=0.1, label='BXU')
pl.plot(tmg['g']   - tmg['r'], tmg['u'] - tmg['g'], marker='.', lw=0., c='b', markersize=2, alpha=0.1, label='TMG')

# pl.plot(yeche['g'] - yeche['r'], yeche['u'] - yeche['g'], marker='.', lw=0., c='c', markersize=2, alpha=0.1, label='YECHE')

pl.plot(stars['g'] - stars['r'], stars['u'] - stars['g'], marker='.', lw=0., c='m', markersize=2, alpha=0.1, label='STARS')

pl.xlim((-1.0, 2.0))
pl.ylim((-1.0, 3.0))

pl.xlabel('g-r')
pl.ylabel('u-g')

pl.legend(frameon=False)

# %%
gmr = np.arange(-1., 2., 0.01)

umg = 1.99 * gmr + 0.68
pl.plot(gmr, umg, c='k', lw=0.5)
pl.axhline(0.88, c='k', lw=0.5)
pl.axvline(1.20, c='k', lw=0.5)

pl.axhline(0.00, c='m', lw=0.5)
pl.axvline(1.20, c='m', lw=0.5)
pl.axhline(3.00, c='m', lw=0.5)
pl.axvline(-0.50, c='m', lw=0.5)

umg = 1.0 + 2.3 * (gmr - 0.35)
pl.plot(gmr, umg, c='m', lw=0.5)
        
pl.xlim((-1.0, 2.0))
pl.ylim((-1.0, 3.5))

pl.xlabel('g-r')
pl.ylabel('u-g')
# Out:
# Text(0, 0.5, 'u-g')

# %%
figure, axes = plt.subplots(1, 4, figsize=(20,5))

axes[0].plot(stars['g'] - stars['r'], stars['u'] - stars['g'], marker='.', lw=0., c='k', markersize=2, alpha=0.1, label='STARS')

axes[1].plot(bxu['g']   - bxu['r'], bxu['u'] - bxu['g'], marker='.', lw=0., c='m', markersize=2, alpha=0.1, label='BXU')
axes[1].plot(stars['g'] - stars['r'], stars['u'] - stars['g'], marker='.', lw=0., c='k', markersize=2, alpha=0.1, label='STARS')

axes[2].plot(tmg['g']   - tmg['r'], tmg['u'] - tmg['g'], marker='.', lw=0., c='c', markersize=2, alpha=0.1, label='TMG')
axes[2].plot(stars['g'] - stars['r'], stars['u'] - stars['g'], marker='.', lw=0., c='k', markersize=2, alpha=0.1, label='STARS')

axes[3].plot(yeche['g'] - yeche['r'], yeche['u'] - yeche['g'], marker='.', lw=0., c='b', markersize=2, alpha=0.1, label='Yeche')
axes[3].plot(stars['g'] - stars['r'], stars['u'] - stars['g'], marker='.', lw=0., c='k', markersize=2, alpha=0.1, label='STARS')

for ax in axes:
    ax.set_xlim((-1.0, 2.0))
    ax.set_ylim((-1.0, 5.5))

    ax.set_xlabel('g-r')
    ax.set_ylabel('u-g')

    ax.legend(frameon=False)

# %%
figure, axes = plt.subplots(1, 4, figsize=(20,5))

axes[0].plot(stars['g'] - stars['r'], stars['u'] - stars['g'], marker='.', lw=0., c='k', markersize=2, alpha=0.1, label='STARS')

axes[1].plot(bxu['g']   - bxu['r'], bxu['u'] - bxu['g'], marker='.', lw=0., c='m', markersize=2, alpha=0.1, label='BXU')
axes[1].plot(stars['g'] - stars['r'], stars['u'] - stars['g'], marker='.', lw=0., c='k', markersize=2, alpha=0.1, label='STARS')

axes[2].plot(tmg['g']   - tmg['r'], tmg['u'] - tmg['g'], marker='.', lw=0., c='c', markersize=2, alpha=0.1, label='TMG')
axes[2].plot(stars['g'] - stars['r'], stars['u'] - stars['g'], marker='.', lw=0., c='k', markersize=2, alpha=0.1, label='STARS')

axes[3].plot(yeche['g'] - yeche['r'], yeche['u'] - yeche['g'], marker='.', lw=0., c='b', markersize=2, alpha=0.1, label='Yeche')
axes[3].plot(stars['g'] - stars['r'], stars['u'] - stars['g'], marker='.', lw=0., c='k', markersize=2, alpha=0.1, label='STARS')

for ax in axes:
    ax.set_xlim((0.0, 1.5))
    ax.set_ylim((0.0, 3.0))

    ax.set_xlabel('g-r')
    ax.set_ylabel('u-g')

    ax.legend(frameon=False)

# %% [markdown]
# # Done.
