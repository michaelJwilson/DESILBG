# %%
import pylab as pl
import numpy as np

from astropy.table import Table

# %%
bxu = Table.read('/global/cscratch1/sd/mjwilson/DESILBG/GOLD/BXU/bxu.fits')
gdrops = Table.read('/global/cscratch1/sd/mjwilson/DESILBG/GOLD/G/g.fits')
tmg = Table.read('/global/cscratch1/sd/mjwilson/DESILBG/GOLD/TMGV9/tmg_v9.fits')

clauds = Table.read('/global/cscratch1/sd/mjwilson/clauds/March2021/COSMOS_v9_v210225.fits')

# %%
bxu.pprint()
# Out:
#    ID           RA                DEC         MASK ... H_err  Ks_err Z_BC03 IDX
# ------- ------------------ ------------------ ---- ... ------ ------ ------ ---
#    8419  149.4617628929257 2.9903850477809484    0 ... 1000.0 1000.0 2.4898   1
#   10770 149.51742685711372  3.028624754635204    0 ... 1000.0 1000.0 2.1522   1
#  100735 149.37250768438415  3.080247775303863    0 ... 1000.0 1000.0 3.7247   1
#  106891 149.26462324656055  3.138785382887629    0 ... 1000.0 1000.0 3.3393   1
#  111902 149.40201064798677  3.188692373436244    0 ... 1000.0 1000.0 0.2653   1
#  179692  149.2142386139038  3.035434124404831    0 ... 1000.0 1000.0 2.8799   1
#  187353 149.21004001927372 3.1048311728256377    0 ... 1000.0 1000.0 2.6679   1
#  281969 148.94066654619888 3.1817781279042285    0 ... 1000.0 1000.0 2.0169   1
#  446575 151.00575262947734   2.99755764912408    0 ... 1000.0 1000.0 2.8128   1
#  447904  151.0352121548275  2.990553891858568    0 ... 1000.0 1000.0 2.2529   1
#     ...                ...                ...  ... ...    ...    ...    ... ...
# 5252339  150.9870525216869 1.5365314200594755    0 ... 1000.0 1000.0 2.8647   8
# 5252415  151.0268976321305 1.5291242704260686    0 ... 1000.0 1000.0  2.948   8
# 5252614 151.05266622660324 1.5698710818120694    0 ... 1000.0 1000.0  2.188   8
# 5253312 151.01470471813647 1.6333125661987211    0 ... 1000.0 1000.0 2.2627   8
# 5253841 150.97606404223887 1.7056557137213704    0 ... 1000.0 1000.0 2.1263   8
# 5254314 150.90054137224266  1.809623158694348    0 ... 1000.0 1000.0 2.7607   8
# 5254591 150.89832403862292  1.847265575819581    0 ... 1000.0 1000.0 2.1731   8
# 5254953 150.95654163469013  1.939906745807463    0 ... 1000.0 1000.0 1.9887   8
# 5254996 150.89816369794585 1.9215185324036328    0 ... 1000.0 1000.0  3.393   8
# 5259167 150.89868742574836  2.612177247731551    0 ... 1000.0 1000.0 2.1388   8
# 5262199 150.89904240288317  2.978026866530625    0 ... 1000.0 1000.0 2.2445   8
# Length = 16747 rows

# %%
gdrops.pprint()
# Out:
#    ID           RA                DEC         MASK ... H_err  Ks_err Z_BC03 IDX
# ------- ------------------ ------------------ ---- ... ------ ------ ------ ---
#   15386 149.44117727168637  3.082920547674356    0 ... 1000.0 1000.0 3.9185   1
#   30429 149.53445212228007 3.2482892478308094    0 ... 1000.0 1000.0 4.4444   1
#   57698 149.46157545840626  3.500348510718072    0 ... 1000.0 1000.0 0.4041   1
#  287021 148.89627872796433 3.1948753416083586    0 ... 1000.0 1000.0 0.3807   1
#  392485 148.63055969636596  2.890567055105118    0 ... 1000.0 1000.0 3.8437   1
#  412504  148.6543556489472 3.1560431159473548    0 ... 1000.0 1000.0 1.3435   1
#  458814 150.90678562027463 3.1372183156621887    0 ... 1000.0 1000.0 0.3995   1
#  578917  150.7922239491414  3.468297531121967    0 ... 1000.0 1000.0 0.2284   1
#  639938 150.70416755701237 3.1741141350279123    0 ... 1000.0 1000.0 0.5584   1
#  800784   150.309652712017 3.0253878363279494    0 ... 1000.0 1000.0 4.2679   1
#     ...                ...                ...  ... ...    ...    ...    ... ...
# 5248941 151.22234049124833 3.0676501455284684    0 ... 1000.0 1000.0 3.8306  12
# 5249111 151.17585466013352  3.057149818789541    0 ... 1000.0 1000.0 2.7497  12
# 5249709 151.07045909980192  1.422042910156718    0 ... 1000.0 1000.0 3.4925  12
# 5250743 150.91487287951057 1.4703738931725774    0 ... 1000.0 1000.0  3.453  12
# 5251648 151.04246973722329 1.5163137545761476    0 ... 1000.0 1000.0 3.4983  12
# 5252150 150.91675937333383 1.5425842006804544    0 ... 1000.0 1000.0 3.4879  12
# 5253136 150.89874470540215 1.5944950399808828    0 ... 1000.0 1000.0 3.4935  12
# 5253582 150.89841341296523  1.682196100140806    0 ... 1000.0 1000.0 3.2876  12
# 5257843 150.90696738177903 2.3612329557270644    0 ... 1000.0 1000.0 3.4682  12
# 5258928 150.95693978820967  2.567155498114048    0 ... 1000.0 1000.0 3.7007  12
# 5262874 151.05398059281617 3.0554298683973222    0 ... 1000.0 1000.0 3.2238  12
# Length = 24803 rows

# %%
tmg.pprint()
# Out:
#    ID           RA                DEC         MASK ... H_err  Ks_err Z_BC03 IDX
# ------- ------------------ ------------------ ---- ... ------ ------ ------ ---
# 2701593 150.61330155313811 1.2814882473135494    0 ... 1000.0 1000.0 2.4626 -99
# 1289080 151.24121601922798 3.1684822801157484    0 ... 1000.0 1000.0 3.0897 -99
#  187353 149.21004001927372 3.1048311728256377    0 ... 1000.0 1000.0 2.6679 -99
# 4850199 149.61243459416568  2.873956889833254    0 ...  -99.0  -99.0 0.1384 -99
# 2919769 149.25140478616885 1.6349077897107656    0 ... 1000.0  -99.0 2.3008 -99
# 2587844 150.81978916811246  1.037446131173854    0 ... 1000.0 1000.0 2.7165 -99
# 2721046 150.55870751605624 1.4665748703386872    0 ... 1000.0 1000.0 0.0752 -99
#  709518 150.47909771682362  2.989020677783287    0 ... 1000.0 1000.0 3.1789 -99
#  100735 149.37250768438415  3.080247775303863    0 ... 1000.0 1000.0 3.7247 -99
# 2439584 151.05095140422483 1.3016694434432885    0 ... 1000.0 1000.0  2.168 -99
#     ...                ...                ...  ... ...    ...    ...    ... ...
# 2584838 150.65372445955094  1.021057896916267    0 ... 1000.0 1000.0 2.3155 -99
# 3586764 151.06015398830127  2.532713403943773    0 ... 1000.0 1000.0 2.3182 -99
# 3485514  151.0059090993179 1.6073826175804782    0 ... 1000.0 1000.0 2.6489 -99
#  537333 150.77033058264448 3.0723948546021447    0 ... 1000.0 1000.0 3.2926 -99
# 4083028 150.51027273400902 2.4632675334032395    0 ...  0.028  0.029 3.2753 -99
# 2546269  150.9620028790942  1.477439134170138    0 ... 1000.0 1000.0 3.2466 -99
# 4359900 149.98209060408703 1.8019118484022527    0 ...  0.027  0.028 2.4687 -99
# 5123623 151.09493996023352 1.6423910261628163    0 ... 1000.0 1000.0 2.0158 -99
# 3800373  150.6852882633291 1.6708900032250302    0 ...  0.078  0.194 0.0711 -99
# 3870142 150.60453131046302 2.2236108833038344    0 ...  0.047  0.073 2.2064 -99
# 2529176 151.01315022739794  1.308891190149812    0 ... 1000.0 1000.0 3.2543 -99
# Length = 10396 rows

# %%
assert np.all(np.sort(tmg['r'].data) == tmg['r'].data)

# %%
clauds.pprint()
# Out:
#    ID           RA                DEC         TRACT ... VMAX_r VMAX_i VMAX_Ks
# ------- ------------------ ------------------ ----- ... ------ ------ -------
#       0 149.41077415981383 2.8837678646168765 10054 ...    0.0    0.0     0.0
#       1  149.5004396199699 2.8835601906535726 10054 ...    0.0    0.0     0.0
#       2 149.47777902724098 2.8835364485539885 10054 ...    0.0    0.0     0.0
#       3  149.5223900145077  2.883879117339179 10054 ...    0.0    0.0     0.0
#       4 149.57957812463238  2.883927791485976 10054 ...    0.0    0.0     0.0
#       5  149.5007466379043 2.8840902577413323 10054 ...    0.0    0.0     0.0
#       6  149.5685019430192 2.8841008564540545 10054 ...    0.0    0.0     0.0
#       7 149.43651392053604  2.883590782997876 10054 ...    0.0    0.0     0.0
#       8 149.41692460974755  2.883848019498321 10054 ...    0.0    0.0     0.0
#       9 149.50635154038002 2.8839203904092745 10054 ...    0.0    0.0     0.0
#     ...                ...                ...   ... ...    ...    ...     ...
# 5263002 151.01685564032772 3.0388443390651005  9814 ...    0.0    0.0     0.0
# 5263003 151.00786271142948  3.040569467380396  9814 ...    0.0    0.0     0.0
# 5263004  150.9996992282793 3.0389332668484874  9814 ...    0.0    0.0     0.0
# 5263005 151.07463689987347 3.0387437835959505  9814 ...    0.0    0.0     0.0
# 5263006 151.00279538546795 3.0386550300345294  9814 ...    0.0    0.0     0.0
# 5263007  151.0727916790391 3.0280709589268184  9814 ...    0.0    0.0     0.0
# 5263008  150.9014593827589 3.0376494167493284  9814 ...    0.0    0.0     0.0
# 5263009 151.01524305291966 3.0373729322856824  9814 ...    0.0    0.0     0.0
# 5263010 151.07689320761486  3.035293912207819  9814 ...    0.0    0.0     0.0
# 5263011 151.02719223082156  3.035915195511509  9814 ...    0.0    0.0     0.0
# 5263012 151.01277357047178 3.0320267240019194  9814 ...    0.0    0.0     0.0
# Length = 5263013 rows

# %% [markdown]
# # BX/U & TMG

# %%
pl.plot(bxu['RA'], bxu['DEC'], marker='.', lw=0.0, c='k', markersize=1)
pl.xlabel('RA')
pl.ylabel('DEC')
pl.title('BX/U/NONDETECT')
pl.savefig('plots/bxu_footprint.pdf')

# %%
pl.plot(bxu['g'] - bxu['r'], bxu['u'] - bxu['g'], marker='.', lw=0.0, c='k', markersize=2)
pl.xlim(-0.6, 1.5)
pl.ylim(-0.5, 7.5)
pl.xlabel('g-r')
pl.ylabel('u-g')
pl.title('BX/U/NONDETECT')
pl.savefig('plots/bxu_colorcolor.pdf')

# %%
isin = (bxu['g'] - bxu['r']) < 0.1

pl.plot(bxu['Z_BC03'][isin], bxu['u'][isin] - bxu['g'][isin], marker='.', lw=0.0, c='k', markersize=2)

pl.xlabel('ZBC03')
pl.ylabel('(u-g) | (g-r) < 0.1')

pl.xlim(-0.5, 6.0)
pl.ylim(-0.5, 7.5)
# Out:
# (-0.5, 7.5)

# %%
pl.plot(tmg['RA'], tmg['DEC'], marker='.', lw=0.0, c='k', markersize=1)
pl.xlabel('RA')
pl.ylabel('DEC')
pl.title('TMG')
pl.savefig('plots/tmg_footprint.pdf')

# %%
pl.plot(tmg['g'] - tmg['r'], tmg['u'] - tmg['g'], marker='.', lw=0.0, c='k', markersize=2)
pl.xlim(-0.6, 1.5)
pl.ylim(-0.5, 7.5)
pl.xlabel('g-r')
pl.ylabel('u-g')
pl.title('TMG')
pl.savefig('plots/tmg_colorcolor.pdf')

# %%
pl.plot(bxu['g'] - bxu['r'], bxu['u'] - bxu['g'], marker='.', lw=0.0, c='k', markersize=2, alpha=0.1, label='BXU')
pl.plot(tmg['g'] - tmg['r'], tmg['u'] - tmg['g'], marker='.', lw=0.0, c='c', markersize=2, alpha=0.1, label='TMG')

pl.xlim(-0.6, 1.5)
pl.ylim(-0.5, 7.5)

pl.xlabel('g-r')
pl.ylabel('u-g')

pl.legend(frameon=False, loc=2)
pl.savefig('plots/colorcolor_comp.pdf')

# %%
_ = pl.hist(bxu['r'], bins=np.arange(17., 25., 0.25))
pl.title('BX/U/NONDETECT')
pl.xlabel('r')
pl.ylabel('Counts per $\Delta r=0.25$')
pl.savefig('plots/bxu_mags.pdf')

# %%
_ = pl.hist(tmg['r'], bins=np.arange(17., 25., 0.25))
pl.title('TMG')
pl.xlabel('r')
pl.ylabel('Counts per $\Delta r=0.25$')
pl.savefig('plots/tmg_mags.pdf')

# %%
# Fraction of tmg sources bright than 23.5
print(np.mean(tmg['r'] < 23.5))
# Out:
# 0.11629472874182378

# %%
# Raw number
print(np.count_nonzero(tmg['r'] < 23.5))
# Out:
# 1209

# %%
_ = pl.hist(bxu['Z_BC03'], bins=np.arange(0.0, 6.0, 0.1))
pl.xlabel('ZBC03')
pl.ylim(0.0, 1800.)
pl.title('BX/U/NONDETECT')
pl.ylabel('Counts per $\Delta z=0.1$')
pl.savefig('plots/bxu_zs.pdf')

# %%
# Interloper fraction.
np.mean(bxu['Z_BC03'] < 1.5)
# Out:
# 0.08831432495372306

# %%
_ = pl.hist(tmg['Z_BC03'], bins=np.arange(0.0, 6.0, 0.1))
pl.xlabel('ZBC03')
pl.ylim(0.0, 1800.)
pl.title('TMG')
pl.ylabel('Counts per $\Delta z=0.1$')
pl.savefig('plots/tmg_zs.pdf')

# %%
# TMG interloper rate.
np.mean(tmg['Z_BC03'] < 1.5)
# Out:
# 0.11398614851866103

# %% [markdown]
# # g drops

# %%
pl.plot(gdrops['RA'], gdrops['DEC'], marker='.', lw=0.0, c='k', markersize=.5)
pl.xlabel('RA')
pl.ylabel('DEC')
pl.title('G/NONDETECT')
pl.savefig('plots/g_footprint.pdf')

# %%
pl.plot(gdrops['r'] - gdrops['i'], gdrops['g'] - gdrops['r'], marker='.', lw=0.0, c='k', markersize=2)
pl.xlim(-2.0, 1.5)
pl.ylim(-0.5, 7.5)
pl.xlabel('r-i')
pl.ylabel('g-r')
pl.title('G')
pl.savefig('plots/g_colorcolor.pdf')

# %%
_ = pl.hist(gdrops['Z_BC03'], bins=np.arange(0.0, 6.0, 0.1))
pl.xlabel('z')
pl.title('g drops')
pl.ylabel('Counts per $\Delta z=0.1$')
pl.savefig('plots/g_zs.pdf')

# %%
# Interloper rate.
np.mean(gdrops['Z_BC03'] < 1.5)
# Out:
# 0.10793049227915978

# %%
_ = pl.hist(gdrops['i'], bins=np.arange(17., 26., 0.25))
pl.title('G/NONDETECT')
pl.xlabel('i')
pl.ylabel('Counts per $\Delta i=0.25$')
pl.savefig('plots/g_mags.pdf')

# %% [markdown]
# # Magnitude comp.

# %%
_ = pl.hist(bxu['r'], bins=np.arange(17., 26., 0.25), label='BX/U/NONDETECT: $r$ detection', histtype='step')
_ = pl.hist(tmg['r'], bins=np.arange(17., 26., 0.25), label='TMG: $r$ detection', histtype='step')
_ = pl.hist(gdrops['i'], bins=np.arange(17., 26., 0.25), label='G/NONDETECT: $i$ detection', histtype='step')

pl.legend(frameon=False, loc=2)
pl.xlabel('$m_{UV}$')
pl.ylabel('Counts per $\Delta m_{UV}=0.25$')
pl.savefig('plots/mags_comp.pdf')

# %% [markdown]
# # Overlap

# %%
hdr = '\tBXU\tG\tTMG'

print(hdr)

for c, clabel in zip([bxu, gdrops, tmg], ['BXU', 'G', 'TMG']):
    row = clabel
    
    for d, dlabel in zip([bxu, gdrops, tmg], ['BXU', 'G', 'TMG']):
        noverlap = len(np.intersect1d(c['ID'], d['ID']))

        row += '\t{}'.format(noverlap)
    
    print(row)
# Out:
# 	BXU	G	TMG
# BXU	16747	241	9512
# G	241	24803	114
# TMG	9512	114	10396

# %% [markdown]
# # Redshift overlap

# %%
_ = pl.hist(bxu['Z_BC03'], bins=np.arange(0.0, 6.0, 0.1), histtype='step', label='BX/U/NONDETECT')
_ = pl.hist(tmg['Z_BC03'], bins=np.arange(0.0, 6.0, 0.1), histtype='step', label='TMG')
_ = pl.hist(gdrops['Z_BC03'], bins=np.arange(0.0, 6.0, 0.1), histtype='step', label='G/NONDETECT')

pl.xlabel('z')
pl.ylim(0.0, 4000.)
pl.ylabel('Counts per $\Delta z=0.1$')
pl.legend(frameon=False, loc=2)
pl.title('BX/U/NONDETECT')
pl.savefig('plots/zs_comp.pdf')

# %% [markdown]
# # Relative priority

# %%
idx = 1 + np.arange(len(bxu))

pl.scatter(idx, bxu['r'], c=bxu['IDX'], marker='.', lw=0.0, s=5)
pl.xlabel('ROW (PRIORITY)')
pl.ylabel('r')
pl.xlim(0.9, 25000)
pl.xscale('log')
pl.colorbar(label='Det. mag. bin')
pl.title('BX/U/NONDETECT')
pl.savefig('plots/bxu_priority.pdf')

# %%
idx = 1 + np.arange(len(gdrops))

pl.scatter(idx, gdrops['i'], c=gdrops['IDX'], marker='.', lw=0.0, s=5)
pl.xlabel('ROW (PRIORITY)')
pl.ylabel('i')
pl.xlim(0.9, 25000)
pl.xscale('log')
pl.colorbar(label='Det. mag. bin')
pl.title('G / NONDETECT')
pl.savefig('plots/g_priority.pdf')

# %%
idx = 1 + np.arange(len(tmg))

pl.scatter(idx, tmg['r'], c='k', marker='.', lw=0.0, s=1)
pl.xlabel('ROW (PRIORITY)')
pl.ylabel('r')
pl.xlim(0.9, 25000)
pl.xscale('log')
pl.title('TMG')
pl.savefig('plots/tmg_priority.pdf')

# %% [markdown]
# # Done.
